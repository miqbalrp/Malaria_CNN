# %% [markdown]
# # Check Data Availability

# %%
import os
import glob

images_dir = r'..\data\cell_images'
malaria_dir = os.path.join(images_dir,'Parasitized')
healthy_dir = os.path.join(images_dir,'Uninfected')

malaria_img = glob.glob(malaria_dir+'\*.png')
healthy_img = glob.glob(healthy_dir+'\*.png')

print('Malaria images : %d' %len(malaria_img))
print('Healthy images : %d' %len(healthy_img))
# Out:
# Malaria images : 13729
# Healthy images : 13729

# %% [markdown]
# # Get a Fraction of Data and Labelling

# %%
import numpy as np
import pandas as pd
import cv2
from tqdm import tqdm

data_frac = 0.5

df = pd.DataFrame({
    'img': malaria_img + healthy_img,
    'label': ['malaria']*len(malaria_img) + ['healthy']*len(healthy_img)
}).sample(frac=data_frac).reset_index(drop=True)

img_num = df.shape[0]

dim1 = []
dim2 = []

for i in range(img_num):
    dim1.append(cv2.imread(df.img[i]).shape[0])
    dim2.append(cv2.imread(df.img[i]).shape[1])
    
df['dim1'] = dim1
df['dim2'] = dim2

df
# Out:
#                                                      img    label  dim1  dim2
# 0      ..\data\cell_images\Uninfected\C211ThinF_IMG_2...  healthy   133   157
# 1      ..\data\cell_images\Uninfected\C206ThinF_IMG_2...  healthy   148   148
# 2      ..\data\cell_images\Uninfected\C206ThinF_IMG_2...  healthy   133   163
# 3      ..\data\cell_images\Parasitized\C132P93ThinF_I...  malaria   127   130
# 4      ..\data\cell_images\Parasitized\C136P97ThinF_I...  malaria   100   145
# ...                                                  ...      ...   ...   ...
# 13724  ..\data\cell_images\Uninfected\C74P35_ThinF_IM...  healthy   151   166
# 13725  ..\data\cell_images\Uninfected\C166P127ThinF_I...  healthy   142   106
# 13726  ..\data\cell_images\Parasitized\C38P3thinF_ori...  malaria   130   148
# 13727  ..\data\cell_images\Parasitized\C80P41ThinF_IM...  malaria   151   181
# 13728  ..\data\cell_images\Uninfected\C189P150ThinF_I...  healthy   112   109
#
# [13729 rows x 4 columns]

# %% [markdown]
# # Take a Look of Image

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

plt.figure(1, figsize=(10,10))

for i in range(16):
    plt.subplot(4,4,i+1)
    plt.subplots_adjust(hspace=0.1,wspace=0.5)
    plt.imshow(cv2.imread(df.img[i]))
    plt.title(df.label[i])
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# # Check Class Balance

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='label', data=df)
plt.title('Number of Each Class in {0:.1f} percent of Data'.format(data_frac*100))

output_dir = r'..\output\image\\'
image_name = output_dir+'Data_Balance.png'
plt.savefig(image_name)

plt.show()

# %% [markdown]
# From chart above we can see that the 50% (randomly choosen) data is pretty balance for training.

# %% [markdown]
# # Check Image Size Distribution

# %%
p = sns.jointplot(data=df,x='dim1',y='dim2', hue='label', s=100, height=10)
p.fig.suptitle("Image Dimension Distribution")
p.ax_joint.collections[0].set_alpha(1)
p.fig.tight_layout()

output_dir = r'..\output\image\\'
image_name = output_dir+'Dimension_Distribution.png'
plt.savefig(image_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9617248a30ef> in <module>
# ----> 1 p = sns.jointplot(data=df,x='dim1',y='dim2', hue='label', s=100, height=10)
#       2 p.fig.suptitle("Image Dimension Distribution")
#       3 p.ax_joint.collections[0].set_alpha(1)
#       4 p.fig.tight_layout()
#       5
#
# NameError: name 'sns' is not defined

# %%
df.describe()
# Out:
#                dim1          dim2
# count  13729.000000  13729.000000
# mean     132.838736    132.352101
# std       20.570061     20.027079
# min       40.000000     46.000000
# 25%      121.000000    121.000000
# 50%      130.000000    130.000000
# 75%      145.000000    142.000000
# max      385.000000    394.000000

# %% [markdown]
# As we can see from plot and statistic above, the first and second dimension of images are varied and normally distributed. We need to standardize the dimension by resizing the image. We choose (130,130) as new dimensions since it's close to median and mean value.

# %%
resize = (32,32)

plt.figure(1, figsize=(10,10))

for i in range(16):
    img = cv2.imread(df.img[i])
    img = cv2.resize(img, resize, interpolation = cv2.INTER_CUBIC)
    plt.subplot(4,4,i+1)
    plt.subplots_adjust(hspace=0.1,wspace=0.5)
    plt.imshow(img)
    plt.title(df.label[i])
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# # Save the Dataframe as Pickle for Next Step

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pickle

dataframe_dir = r'..\data'
with open(dataframe_dir+'\dataframe.pickle','wb') as f:
    pickle.dump(df, f)
